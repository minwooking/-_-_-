# %%
pip install split-folders
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

import os
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
import pandas as pd
from glob import glob
import pathlib
from PIL import Image
import time
from tqdm import tqdm
os.listdir()


import splitfolders as spf

# %%
# df = pd.read_csv('original_test2_up.csv')
# y=df.iloc[0:,0].astype('category').cat.codes
# y.value_counts().keys

# %%
# glob('C:\workspace\eatand_medicinal_plant\\22011data\*\\*\\*\\*.jpg')[0]
len(glob('C:\workspace\eatand_medicinal_plant\\학습용데이터\*\\*\\*\\*\\'))
# 7220 장의 이미지가 있음
# Out:
# 36

# %%
for i,a in tqdm(enumerate(glob('C:\workspace\eatand_medicinal_plant\\학습용데이터\*\\*\\*\\*\\*.jpg'))):
    globals()[f'image{i}'] = Image.open(a)# 불러온 이미지 파일의 사이즈를 각각의 변수에 언패킹
    globals()[f'image{i}'], globals()[f'Ydim{i}'] = globals()[f'image{i}'].size# 이미지 리사이징 (원본 크기에 상관없이 x, y 사이즈로 변경됨)
    # globals()[f'image{i}'] = globals()[f'image{i}'].resize((28, 28))
    globals()[f'image{i}']
# Out:
# 10127it [00:38, 259.96it/s]

# %%
# dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
# data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
# data_dir = pathlib.Path(data_dir)

# %%
glob(train_메밀_dir+'\\*')
# Out:
# []

# %%
glob('C:\workspace\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\original\\메밀\\*')
# Out:
# ['C:\\workspace\\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\original\\메밀\\CR009_02_50014a.jpg',
#  'C:\\workspace\\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\original\\메밀\\CR009_02_50015.jpg',
#  'C:\\workspace\\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\original\\메밀\\CR009_02_50017a.jpg',
#  'C:\\workspace\\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\original\\메밀\\CR009_02_50018a.jpg',
#  'C:\\workspace\\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\original\\메밀\\CR009_02_50019.jpg',
#  'C:\\workspace\\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\original\\메밀\\CR009_02_50021.jpg',
#  'C:\\workspace\\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\original\\메밀\\CR009_02_50023.jpg',
#  'C:\\workspace\\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\original\\메밀\\CR009_02_50044d.jpg',
#  'C:\\workspace\\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\original\\메밀\\CR009_02_50044h.jpg',
# ...

# %%
path = 'C:\workspace\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\original'
path_train = 'C:\workspace\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\train'
path_test = 'C:\workspace\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\test'
path_validation = 'C:\workspace\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\validation'
메밀= glob(path+"\\메밀"+'\\*')
참꽃나무=glob(path+"\\참꽃나무"+'\\*')
큰조롱= glob(path+"\\큰조롱"+'\\*')
해국=glob(path+"\\해국"+'\\*')
황근=glob(path+"\\황근"+'\\*')

train_메밀_dir = os.path.join(path_train, '메밀')
train_참꽃나무_dir = os.path.join(path_train, '참꽃나무')
train_큰조롱_dir = os.path.join(path_train, '큰조롱')
train_해국_dir = os.path.join(path_train, '해국')
train_황근_dir = os.path.join(path_train, '황근')

validation_황근_dir = os.path.join(path_validation, '황근')
validation_메밀_dir = os.path.join(path_validation, '메밀')
validation_참꽃나무_dir = os.path.join(path_validation, '참꽃나무')
validation_큰조롱_dir = os.path.join(path_validation, '큰조롱')
validation_해국_dir = os.path.join(path_validation, '해국')

test_큰조롱_dir = os.path.join(path_test, '큰조롱')
test_해국_dir = os.path.join(path_test, '해국')
test_황근_dir = os.path.join(path_test, '황근')
test_메밀_dir = os.path.join(path_test, '메밀')
test_참꽃나무_dir = os.path.join(path_test, '참꽃나무')

# %%
train_메밀_dir
# Out:
# 'C:\\workspace\\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\train\\메밀'

# %%
def rename(files):
    if '메밀' in files[0]:
        for i,f in enumerate(files):
            os.rename(f, os.path.join(path+"\\메밀",path)

# %%
spf.ratio('C:\workspace\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\original\\메밀\\',output='C:\workspace\eatand_medicinal_plant\\22011data\\01.orignaldata\\꽃\\')
